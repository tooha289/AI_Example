# %% [markdown]
# ## 타이타닉 데이터 VIF 예제
# * target: Servived
# * Passengerid, name, Ticket, Cabin 컬럼은 삭제
# * Nan 데이터는 삭제
# * Sex, Embarked는 레이블 인코딩

# %%
import numpy as np
import pandas as pd

from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

from library.preprocessing import DataFramePreprocessor
from library.preprocessing import FeatureSelector

# %%
titanic = pd.read_csv("data/titanic_train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 컬럼 제거

# %%
titanic.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis=1, inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
titanic.describe(include="all")
# Out:
#           Survived      Pclass   Sex         Age       SibSp       Parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               Fare Embarked
# count   891.000000      889
# unique         NaN        3
# top            NaN        S
# freq           NaN      644
# mean     32.204208      NaN
# std      49.693429      NaN
# min       0.000000      NaN
# 25%       7.910400      NaN
# 50%      14.454200      NaN
# 75%      31.000000      NaN
# max     512.329200      NaN

# %% [markdown]
# ## LabelEncoding

# %% [markdown]
# ### Sex, Embarked는 레이블 인코딩

# %%
lbe = LabelEncoder()
dfp = DataFramePreprocessor()

# %%
df, tfs = dfp.fit_transform_single_transformer(titanic, lbe, ['Sex', 'Embarked'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sex       891 non-null    int32
#  1   Embarked  891 non-null    int32
# dtypes: int32(2)
# memory usage: 7.1 KB

# %%
titanic.update(df)
titanic[['Sex', 'Embarked']] = titanic[['Sex', 'Embarked']].astype("int32")
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int32
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int32
# dtypes: float64(2), int32(2), int64(4)
# memory usage: 48.9 KB

# %%
titanic
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.0      1      0   7.2500         2
# 1           1       1    0  38.0      1      0  71.2833         0
# 2           1       3    0  26.0      0      0   7.9250         2
# 3           1       1    0  35.0      1      0  53.1000         2
# 4           0       3    1  35.0      0      0   8.0500         2
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    1  27.0      0      0  13.0000         2
# 887         1       1    0  19.0      0      0  30.0000         2
# 888         0       3    0   NaN      1      2  23.4500         2
# 889         1       1    1  26.0      0      0  30.0000         0
# 890         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %% [markdown]
# ## 널 값 처리

# %% [markdown]
# ### Case1. Null 제거

# %%
no_null_titanic = titanic.dropna(axis=0)
no_null_titanic
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.0      1      0   7.2500         2
# 1           1       1    0  38.0      1      0  71.2833         0
# 2           1       3    0  26.0      0      0   7.9250         2
# 3           1       1    0  35.0      1      0  53.1000         2
# 4           0       3    1  35.0      0      0   8.0500         2
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 885         0       3    0  39.0      0      5  29.1250         1
# 886         0       2    1  27.0      0      0  13.0000         2
# 887         1       1    0  19.0      0      0  30.0000         2
# 889         1       1    1  26.0      0      0  30.0000         0
# 890         0       3    1  32.0      0      0   7.7500         1
#
# [714 rows x 8 columns]

# %%
no_null_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  714 non-null    int64
#  1   Pclass    714 non-null    int64
#  2   Sex       714 non-null    int32
#  3   Age       714 non-null    float64
#  4   SibSp     714 non-null    int64
#  5   Parch     714 non-null    int64
#  6   Fare      714 non-null    float64
#  7   Embarked  714 non-null    int32
# dtypes: float64(2), int32(2), int64(4)
# memory usage: 44.6 KB

# %% [markdown]
# # VIF 분석

# %%
def get_vif(formula, df):
    y, X = dmatrices(formula, df, return_type="dataframe")
    
    vif = pd.DataFrame()
    vif["features"] = X.columns
    vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

# %%
no_null_titanic.columns.difference(['Survived'])
# Out:
# Index(['Age', 'Embarked', 'Fare', 'Parch', 'Pclass', 'Sex', 'SibSp'], dtype='object')

# %%
formula = "Survived~" + "+".join(no_null_titanic.columns.difference(['Survived']))
formula
# Out:
# 'Survived~Age+Embarked+Fare+Parch+Pclass+Sex+SibSp'

# %%
get_vif(formula, no_null_titanic)
# Out:
#     features  VIF Factor
# 0  Intercept   32.422909
# 1        Age    1.314650
# 2   Embarked    1.107727
# 3       Fare    1.642829
# 4      Parch    1.287749
# 5     Pclass    1.756618
# 6        Sex    1.117924
# 7      SibSp    1.277192

# %%
fs = FeatureSelector()
fs.vif_analysis(formula, titanic)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     67.92
# Date:                Fri, 08 Sep 2023   Prob (F-statistic):           8.65e-75
# Time:                        01:52:22   Log-Likelihood:                -321.61
# No. Observations:                 714   AIC:                             659.2
# Df Residuals:                     706   BIC:                             695.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4012      0.081     17.223      0.000       1.241       1.561
# Age           -0.0064      0.001     -5.699      0.000      -0.009      -0.004
# Embarked      -0.0282      0.019     -1.465      0.143      -0.066       0.010
# Fare           0.0002      0.000      0.613      0.540      -0.000       0.001
# Parch         -0.0107      0.019     -0.560      0.576      -0.048       0.027
# Pclass        -0.1908      0.023     -8.441      0.000      -0.235      -0.146
# Sex           -0.4859      0.031    -15.489      0.000      -0.547      -0.424
# SibSp         -0.0520      0.017     -2.990      0.003      -0.086      -0.018
# ==============================================================================
# Omnibus:                       25.891   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.009
# Skew:                           0.485   Prob(JB):                     8.28e-07
# Kurtosis:                       3.036   Cond. No.                         387.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  features  VIF Factor
# Intercept   32.422909
#    Pclass    1.756618
#      Fare    1.642829
#       Age    1.314650
#     Parch    1.287749
#     SibSp    1.277192
#       Sex    1.117924
#  Embarked    1.107727
# Remove the Intercept feature with a VIF greater than 10.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Survived   R-squared (uncentered):                   0.496
# Model:                            OLS   Adj. R-squared (uncentered):              0.491
# Method:                 Least Squares   F-statistic:                              99.41
# Date:                Fri, 08 Sep 2023   Prob (F-statistic):                   7.84e-101
# Time:                        01:52:22   Log-Likelihood:                         -446.83
# No. Observations:                 714   AIC:                                      907.7
# Df Residuals:                     707   BIC:                                      939.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0057      0.001      5.369      0.000       0.004       0.008
# Embarked       0.0710      0.022      3.243      0.001       0.028       0.114
# Fare           0.0034      0.000      9.892      0.000       0.003       0.004
# Parch         -0.0026      0.023     -0.115      0.908      -0.047       0.042
# Pclass         0.1064      0.017      6.119      0.000       0.072       0.141
# Sex           -0.4218      0.037    -11.371      0.000      -0.495      -0.349
# SibSp         -0.0134      0.021     -0.652      0.515      -0.054       0.027
# ==============================================================================
# Omnibus:                       52.146   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.602
# Skew:                           0.431   Prob(JB):                     1.86e-08
# Kurtosis:                       2.326   Cond. No.                         149.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# features  VIF Factor
#   Pclass    5.958718
# Embarked    5.239716
#      Age    4.182646
#      Sex    3.015141
#     Fare    1.664631
#    SibSp    1.638253
#    Parch    1.616347
# The analysis ends because there are no VIF values exceeding 10.

# %% [markdown]
# ## Permutation_importance 분석

# %%
from sklearn.inspection import permutation_importance

# %%
y, X = dmatrices(formula, titanic, return_type="dataframe")

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Permutation Importance 계산
perm_importance = permutation_importance(dtc, X, y)

# 피처별 중요도 출력
print("피처 중요도:", perm_importance.importances_mean)
# Out:
# 피처 중요도: [0.         0.25686275 0.04621849 0.16638655 0.02521008 0.20336134
#  0.2535014  0.05658263]

# %%
X.columns
# Out:
# Index(['Intercept', 'Age', 'Embarked', 'Fare', 'Parch', 'Pclass', 'Sex',
#        'SibSp'],
#       dtype='object')

# %%
pi = pd.DataFrame()
pi["feature"] = X.columns
pi["perm_importance"] = perm_importance.importances_mean

# %%
pi
# Out:
#      feature  perm_importance
# 0  Intercept         0.000000
# 1        Age         0.256863
# 2   Embarked         0.046218
# 3       Fare         0.166387
# 4      Parch         0.025210
# 5     Pclass         0.203361
# 6        Sex         0.253501
# 7      SibSp         0.056583

# %%
fs.get_permutation_importance(dtc, X, y)
# Out:
#      feature  perm_importance
# 0  Intercept         0.000000
# 1        Age         0.248739
# 2   Embarked         0.049020
# 3       Fare         0.163305
# 4      Parch         0.023529
# 5     Pclass         0.197479
# 6        Sex         0.254062
# 7      SibSp         0.060504
