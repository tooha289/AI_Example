# %% [markdown]
# # 인터넷 신규 가입 여부 예측 실습 예제
# * 데이터 로드
#     * pd.read_csv('newbie.csv‘)
# * 종속 변수 : 'Newbie‘
# * 독립 변수 제거 : 'who', 'Country', 'Years on Internet‘
# * 결측값 제거 :
#     * Age : 평균
#     * Household Income, Sexual Preference, Marital Status : 최빈값으로 채움
# * 범주형 독립변수 데이터 타입 "category"로 변환 후 더미 변수로 변환(원핫인코딩 처리)
#     * pd.get_dummies() 사용
#     * 사용예)
#     * import pandas as pd
#     * fruit = pd.DataFrame({'name':['apple', 'banana', 'cherry', 'durian', np.nan],
#         'color':['red', 'yellow', 'red', 'green', np.nan]})
#     * pd.get_dummies(fruit)

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from library.preprocessing import DataFramePreprocessor

# %%
newbie = pd.read_csv('data/newbie.csv')
newbie
# Out:
#            who  Newbie   Age  Gender Household Income Sexual Preference  \
# 0      id74364       0  54.0    Male           $50-74          Gay male
# 1      id84505       0  39.0  Female        Over $100      Heterosexual
# 2      id84509       1  49.0  Female           $40-49      Heterosexual
# 3      id87028       1  22.0  Female           $40-49      Heterosexual
# 4      id76087       0  20.0    Male           $30-39          Bisexual
# ...        ...     ...   ...     ...              ...               ...
# 19578  id83400       0  22.0    Male        Over $100      Heterosexual
# 19579  id72216       0  19.0    Male              NaN      Heterosexual
# 19580   id8654       0  49.0  Female           $50-74      Heterosexual
# 19581  id84503       1  42.0  Female           $50-74      Heterosexual
# 19582  id87674       0  24.0  Female           $50-74       Transgender
#
#           Country Education Attainment Major Occupation Marital Status  \
# 0         Ontario         Some College         Computer          Other
# 1          Sweden         Professional            Other          Other
# 2      Washington         Some College       Management          Other
# 3         Florida         Some College         Computer        Married
# 4      New Jersey         Some College        Education         Single
# ...           ...                  ...              ...            ...
# 19578       Texas         Some College        Education         Single
# 19579  New Jersey         Some College        Education         Single
# 19580    Missouri             Doctoral        Education        Married
# 19581    Kentucky         Some College            Other        Married
# 19582  California              College         Computer         Single
#
#       Years on Internet
# 0                4-6 yr
# 1                1-3 yr
# 2            Under 6 mo
# 3               6-12 mo
# 4                1-3 yr
# ...                 ...
# 19578            4-6 yr
# 19579            4-6 yr
# 19580            1-3 yr
# 19581        Under 6 mo
# 19582            1-3 yr
#
# [19583 rows x 11 columns]

# %%
newbie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   who                   19583 non-null  object
#  1   Newbie                19583 non-null  int64
#  2   Age                   19022 non-null  float64
#  3   Gender                19583 non-null  object
#  4   Household Income      16398 non-null  object
#  5   Sexual Preference     18291 non-null  object
#  6   Country               19583 non-null  object
#  7   Education Attainment  19583 non-null  object
#  8   Major Occupation      19583 non-null  object
#  9   Marital Status        19240 non-null  object
#  10  Years on Internet     19583 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1.6+ MB

# %%
newbie.describe(include='all').T
# Out:
#                         count unique           top   freq       mean  \
# who                     19583  19583       id74364      1        NaN
# Newbie                19583.0    NaN           NaN    NaN   0.253383
# Age                   19022.0    NaN           NaN    NaN  35.222269
# Gender                  19583      2          Male  13454        NaN
# Household Income        16398      8        $50-74   3935        NaN
# Sexual Preference       18291      6  Heterosexual  16869        NaN
# Country                 19583    142    California   2312        NaN
# Education Attainment    19583      9       College   6194        NaN
# Major Occupation        19583      5      Computer   5921        NaN
# Marital Status          19240      6       Married   8742        NaN
# Years on Internet       19583      5        1-3 yr   8615        NaN
#
#                             std  min   25%   50%   75%   max
# who                         NaN  NaN   NaN   NaN   NaN   NaN
# Newbie                 0.434959  0.0   0.0   0.0   1.0   1.0
# Age                   12.642339  5.0  25.0  33.0  44.0  80.0
# Gender                      NaN  NaN   NaN   NaN   NaN   NaN
# Household Income            NaN  NaN   NaN   NaN   NaN   NaN
# Sexual Preference           NaN  NaN   NaN   NaN   NaN   NaN
# Country                     NaN  NaN   NaN   NaN   NaN   NaN
# Education Attainment        NaN  NaN   NaN   NaN   NaN   NaN
# Major Occupation            NaN  NaN   NaN   NaN   NaN   NaN
# Marital Status              NaN  NaN   NaN   NaN   NaN   NaN
# Years on Internet           NaN  NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# # 독립 변수 제거

# %%
newbie = newbie.drop(['who', 'Country', 'Years on Internet'], axis=1)
newbie
# Out:
#        Newbie   Age  Gender Household Income Sexual Preference  \
# 0           0  54.0    Male           $50-74          Gay male
# 1           0  39.0  Female        Over $100      Heterosexual
# 2           1  49.0  Female           $40-49      Heterosexual
# 3           1  22.0  Female           $40-49      Heterosexual
# 4           0  20.0    Male           $30-39          Bisexual
# ...       ...   ...     ...              ...               ...
# 19578       0  22.0    Male        Over $100      Heterosexual
# 19579       0  19.0    Male              NaN      Heterosexual
# 19580       0  49.0  Female           $50-74      Heterosexual
# 19581       1  42.0  Female           $50-74      Heterosexual
# 19582       0  24.0  Female           $50-74       Transgender
#
#       Education Attainment Major Occupation Marital Status
# 0             Some College         Computer          Other
# 1             Professional            Other          Other
# 2             Some College       Management          Other
# 3             Some College         Computer        Married
# 4             Some College        Education         Single
# ...                    ...              ...            ...
# 19578         Some College        Education         Single
# 19579         Some College        Education         Single
# 19580             Doctoral        Education        Married
# 19581         Some College            Other        Married
# 19582              College         Computer         Single
#
# [19583 rows x 8 columns]

# %% [markdown]
# # 결측값 처리

# %% [markdown]
# ## Age : 평균

# %%
newbie['Age'].fillna(newbie['Age'].mean(), inplace=True)

# %%
newbie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Newbie                19583 non-null  int64
#  1   Age                   19583 non-null  float64
#  2   Gender                19583 non-null  object
#  3   Household Income      16398 non-null  object
#  4   Sexual Preference     18291 non-null  object
#  5   Education Attainment  19583 non-null  object
#  6   Major Occupation      19583 non-null  object
#  7   Marital Status        19240 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Household Income, Sexual Preference, Marital Status : 최빈값으로 채움

# %%
newbie['Household Income'].fillna(newbie['Household Income'].mode()[0], inplace=True)
newbie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Newbie                19583 non-null  int64
#  1   Age                   19583 non-null  float64
#  2   Gender                19583 non-null  object
#  3   Household Income      19583 non-null  object
#  4   Sexual Preference     18291 non-null  object
#  5   Education Attainment  19583 non-null  object
#  6   Major Occupation      19583 non-null  object
#  7   Marital Status        19240 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
newbie['Sexual Preference'].fillna(newbie['Sexual Preference'].mode()[0], inplace=True)
newbie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Newbie                19583 non-null  int64
#  1   Age                   19583 non-null  float64
#  2   Gender                19583 non-null  object
#  3   Household Income      19583 non-null  object
#  4   Sexual Preference     19583 non-null  object
#  5   Education Attainment  19583 non-null  object
#  6   Major Occupation      19583 non-null  object
#  7   Marital Status        19240 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
newbie['Marital Status'].fillna(newbie['Marital Status'].mode()[0], inplace=True)
newbie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Newbie                19583 non-null  int64
#  1   Age                   19583 non-null  float64
#  2   Gender                19583 non-null  object
#  3   Household Income      19583 non-null  object
#  4   Sexual Preference     19583 non-null  object
#  5   Education Attainment  19583 non-null  object
#  6   Major Occupation      19583 non-null  object
#  7   Marital Status        19583 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
newbie.isnull().sum()
# Out:
# Newbie                  0
# Age                     0
# Gender                  0
# Household Income        0
# Sexual Preference       0
# Education Attainment    0
# Major Occupation        0
# Marital Status          0
# dtype: int64

# %% [markdown]
# # 범주형 독립변수 데이터 타입 "category"로 변환 후 원핫인코딩

# %%
newbie
# Out:
#        Newbie   Age  Gender Household Income Sexual Preference  \
# 0           0  54.0    Male           $50-74          Gay male
# 1           0  39.0  Female        Over $100      Heterosexual
# 2           1  49.0  Female           $40-49      Heterosexual
# 3           1  22.0  Female           $40-49      Heterosexual
# 4           0  20.0    Male           $30-39          Bisexual
# ...       ...   ...     ...              ...               ...
# 19578       0  22.0    Male        Over $100      Heterosexual
# 19579       0  19.0    Male           $50-74      Heterosexual
# 19580       0  49.0  Female           $50-74      Heterosexual
# 19581       1  42.0  Female           $50-74      Heterosexual
# 19582       0  24.0  Female           $50-74       Transgender
#
#       Education Attainment Major Occupation Marital Status
# 0             Some College         Computer          Other
# 1             Professional            Other          Other
# 2             Some College       Management          Other
# 3             Some College         Computer        Married
# 4             Some College        Education         Single
# ...                    ...              ...            ...
# 19578         Some College        Education         Single
# 19579         Some College        Education         Single
# 19580             Doctoral        Education        Married
# 19581         Some College            Other        Married
# 19582              College         Computer         Single
#
# [19583 rows x 8 columns]

# %%
categorical_cols = ['Gender', 'Household Income', 'Sexual Preference',
                    'Education Attainment', 'Major Occupation', 'Marital Status']
numeric_cols = ['Age']

# %%
newbie[categorical_cols] = newbie.loc[:, categorical_cols].astype('category')

# %%
newbie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Newbie                19583 non-null  int64
#  1   Age                   19583 non-null  float64
#  2   Gender                19583 non-null  category
#  3   Household Income      19583 non-null  category
#  4   Sexual Preference     19583 non-null  category
#  5   Education Attainment  19583 non-null  category
#  6   Major Occupation      19583 non-null  category
#  7   Marital Status        19583 non-null  category
# dtypes: category(6), float64(1), int64(1)
# memory usage: 422.3 KB

# %% [markdown]
# ## MinMax Scaling과 OneHot Encoding 수행

# %%
dfp = DataFramePreprocessor()
mms = MinMaxScaler()
ohe = OneHotEncoder(dtype="uint8")

# %%
df_X, tfs = dfp.fit_transform_multiple_transformer(newbie, [mms, ohe], [numeric_cols, categorical_cols])
df_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                19583 non-null  float64
#  1   Gender_Female                      19583 non-null  uint8
#  2   Gender_Male                        19583 non-null  uint8
#  3   Household Income_$10-19            19583 non-null  uint8
#  4   Household Income_$20-29            19583 non-null  uint8
#  5   Household Income_$30-39            19583 non-null  uint8
#  6   Household Income_$40-49            19583 non-null  uint8
#  7   Household Income_$50-74            19583 non-null  uint8
#  8   Household Income_$75-99            19583 non-null  uint8
#  9   Household Income_Over $100         19583 non-null  uint8
#  10  Household Income_Under $10         19583 non-null  uint8
#  11  Sexual Preference_Bisexual         19583 non-null  uint8
#  12  Sexual Preference_Gay male         19583 non-null  uint8
#  13  Sexual Preference_Heterosexual     19583 non-null  uint8
#  14  Sexual Preference_Lesbian          19583 non-null  uint8
#  15  Sexual Preference_Transgender      19583 non-null  uint8
#  16  Sexual Preference_na               19583 non-null  uint8
#  17  Education Attainment_College       19583 non-null  uint8
#  18  Education Attainment_Doctoral      19583 non-null  uint8
#  19  Education Attainment_Grammar       19583 non-null  uint8
#  20  Education Attainment_High School   19583 non-null  uint8
#  21  Education Attainment_Masters       19583 non-null  uint8
#  22  Education Attainment_Other         19583 non-null  uint8
#  23  Education Attainment_Professional  19583 non-null  uint8
#  24  Education Attainment_Some College  19583 non-null  uint8
#  25  Education Attainment_Special       19583 non-null  uint8
#  26  Major Occupation_Computer          19583 non-null  uint8
#  27  Major Occupation_Education         19583 non-null  uint8
#  28  Major Occupation_Management        19583 non-null  uint8
#  29  Major Occupation_Other             19583 non-null  uint8
#  30  Major Occupation_Professional      19583 non-null  uint8
#  31  Marital Status_Divorced            19583 non-null  uint8
#  32  Marital Status_Married             19583 non-null  uint8
#  33  Marital Status_Other               19583 non-null  uint8
#  34  Marital Status_Separated           19583 non-null  uint8
#  35  Marital Status_Single              19583 non-null  uint8
#  36  Marital Status_Widowed             19583 non-null  uint8
# dtypes: float64(1), uint8(36)
# memory usage: 841.6 KB

# %%
df_y = newbie['Newbie']

# %% [markdown]
# # 데이터 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size=0.33, random_state=1)
X_train.head()
# Out:
#             Age  Gender_Female  Gender_Male  Household Income_$10-19  \
# 17107  0.706667              0            1                        0
# 112    0.546667              1            0                        0
# 17900  0.373333              0            1                        0
# 8497   0.306667              0            1                        0
# 16655  0.320000              1            0                        0
#
#        Household Income_$20-29  Household Income_$30-39  \
# 17107                        0                        0
# 112                          0                        0
# 17900                        0                        0
# 8497                         0                        0
# 16655                        0                        1
#
#        Household Income_$40-49  Household Income_$50-74  \
# 17107                        0                        0
# 112                          0                        0
# 17900                        0                        1
# 8497                         0                        1
# 16655                        0                        0
#
#        Household Income_$75-99  Household Income_Over $100  ...  \
# 17107                        1                           0  ...
# 112                          1                           0  ...
# 17900                        0                           0  ...
# 8497                         0                           0  ...
# 16655                        0                           0  ...
#
#        Major Occupation_Education  Major Occupation_Management  \
# 17107                           0                            0
# 112                             0                            1
# 17900                           1                            0
# 8497                            0                            0
# 16655                           0                            0
#
#        Major Occupation_Other  Major Occupation_Professional  \
# 17107                       0                              0
# 112                         0                              0
# 17900                       0                              0
# 8497                        0                              0
# 16655                       0                              1
#
#        Marital Status_Divorced  Marital Status_Married  Marital Status_Other  \
# 17107                        0                       1                     0
# 112                          0                       1                     0
# 17900                        0                       1                     0
# 8497                         0                       1                     0
# 16655                        1                       0                     0
#
#        Marital Status_Separated  Marital Status_Single  Marital Status_Widowed
# 17107                         0                      0                       0
# 112                           0                      0                       0
# 17900                         0                      0                       0
# 8497                          0                      0                       0
# 16655                         0                      0                       0
#
# [5 rows x 37 columns]

# %% [markdown]
# # 로지스틱 회귀 수행

# %%
log_clf = LogisticRegression()
log_clf.fit(X_train, y_train)
log_clf.score(X_test, y_test)
# Out:
# 0.7630638297872341
